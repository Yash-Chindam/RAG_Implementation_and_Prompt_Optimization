# %%
# !pip install transformers sentence-transformers langchain
# !pip install -U langchain-community
# !pip install PyPDF2
# !pip install faiss-cpu
# !pip install langchain_huggingface
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (3.2.1)
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.3.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.5.0+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.10.10)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.12 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.13)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.1.137)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.12->langchain) (1.33)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.10)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.12->langchain) (3.0.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.2)
# Collecting langchain-community
#   Downloading langchain_community-0.3.4-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (3.10.10)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting httpx-sse<0.5.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting langchain<0.4.0,>=0.3.6 (from langchain-community)
#   Downloading langchain-0.3.6-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain-core<0.4.0,>=0.3.14 (from langchain-community)
#   Downloading langchain_core-0.3.15-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.1.137)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (1.26.4)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.6.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.17.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.23.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.4.0,>=0.3.6->langchain-community) (0.3.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain<0.4.0,>=0.3.6->langchain-community) (2.9.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.14->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.14->langchain-community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.14->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (3.10.10)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (1.0.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (1.0.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.14->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.6->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.6->langchain-community) (2.23.4)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain-community) (0.2.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (1.2.2)
# Downloading langchain_community-0.3.4-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 42.7 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading langchain-0.3.6-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 44.9 MB/s eta 0:00:00
# Downloading langchain_core-0.3.15-py3-none-any.whl (408 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.7/408.7 kB 28.6 MB/s eta 0:00:00
# Downloading pydantic_settings-2.6.0-py3-none-any.whl (28 kB)
# Downloading marshmallow-3.23.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.5 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: python-dotenv, mypy-extensions, marshmallow, httpx-sse, typing-inspect, pydantic-settings, dataclasses-json, langchain-core, langchain, langchain-community
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.13
#     Uninstalling langchain-core-0.3.13:
#       Successfully uninstalled langchain-core-0.3.13
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.4
#     Uninstalling langchain-0.3.4:
#       Successfully uninstalled langchain-0.3.4
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain-0.3.6 langchain-community-0.3.4 langchain-core-0.3.15 marshmallow-3.23.0 mypy-extensions-1.0.0 pydantic-settings-2.6.0 python-dotenv-1.0.1 typing-inspect-0.9.0
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 8.7 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (24.1)
# Downloading faiss_cpu-1.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 49.3 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.9.0
# Collecting langchain_huggingface
#   Downloading langchain_huggingface-0.1.1-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langchain_huggingface) (0.24.7)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.13 in /usr/local/lib/python3.10/dist-packages (from langchain_huggingface) (0.3.15)
# Requirement already satisfied: sentence-transformers>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from langchain_huggingface) (3.2.1)
# Requirement already satisfied: tokenizers>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from langchain_huggingface) (0.19.1)
# Requirement already satisfied: transformers>=4.39.0 in /usr/local/lib/python3.10/dist-packages (from langchain_huggingface) (4.44.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (4.66.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.13->langchain_huggingface) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.13->langchain_huggingface) (0.1.137)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.13->langchain_huggingface) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.13->langchain_huggingface) (9.0.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (2.5.0+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.13.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (10.4.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.39.0->langchain_huggingface) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.39.0->langchain_huggingface) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.39.0->langchain_huggingface) (0.4.5)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.13->langchain_huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.13->langchain_huggingface) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.13->langchain_huggingface) (3.10.10)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.13->langchain_huggingface) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.13->langchain_huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.13->langchain_huggingface) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (2024.8.30)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (1.3.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface) (3.5.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.13->langchain_huggingface) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.13->langchain_huggingface) (1.0.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.13->langchain_huggingface) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.13->langchain_huggingface) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.0.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.13->langchain_huggingface) (1.2.2)
# Downloading langchain_huggingface-0.1.1-py3-none-any.whl (21 kB)
# Installing collected packages: langchain_huggingface
# Successfully installed langchain_huggingface-0.1.1

# %%
import os
from google.colab import userdata
from huggingface_hub import InferenceClient
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
import transformers
from transformers import AutoModelForSequenceClassification, AutoTokenizer
from PyPDF2 import PdfReader

# %%
sec_key=userdata.get("HUGGINGFACEHUB_API_TOKEN")
os.environ["HUGGINGFACEHUB_API_TOKEN"]=sec_key

# %%
model_name = "microsoft/layoutlm-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)
embedder = HuggingFaceEmbeddings(model_name="all-mpnet-base-v2")

def extract_text_from_pdf(pdf_file_path):
    text = ""
    with open(pdf_file_path, 'rb') as f:
        pdf_reader = PdfReader(f)
        for page in pdf_reader.pages:
            text += page.extract_text()
    return text

def extract_text_from_multiple_pdfs(pdf_file_paths):
    combined_text = ""
    for pdf_file_path in pdf_file_paths:
        combined_text += extract_text_from_pdf(pdf_file_path)
    return combined_text

def recursive_split_text(text, max_length=1000):
    if len(text) <= max_length:
        return [text]

    split_index = text.rfind(' ', 0, max_length)
    if split_index == -1:
        split_index = max_length

    return recursive_split_text(text[:split_index]) + recursive_split_text(text[split_index:].strip())

def create_faiss_index(text_data, embedder):
    chunks = recursive_split_text(text_data)
    vectorstore = FAISS.from_texts(chunks, embedder)
    return vectorstore

def handle_user_input(user_question, vectorstore, conversation_history):
    retriever = vectorstore.as_retriever()
    relevant_text = retriever.get_relevant_documents(user_question)

    response = generate_response_from_inference_api(user_question, relevant_text, conversation_history)

    conversation_history.append({"user": user_question, "bot": response})
    return response

def format_conversation_history(conversation_history):
    """Formats conversation history for prompt generation."""
    formatted_history = "\n".join(
        f"You: {entry['user']}\nBot: {entry['bot']}" for entry in conversation_history
    )
    return formatted_history

def generate_response_from_inference_api(user_question, relevant_text, conversation_history):
    sec_key = os.getenv("HUGGINGFACEHUB_API_TOKEN")

    prompt = f"""
    You are an assistant that provides detailed answers based on the content of multiple PDF documents and the conversation history.

    Here is the relevant information extracted from the PDFs:
    {relevant_text}

    Here is the history of the conversation so far:
    {format_conversation_history(conversation_history)}

    The user has asked the following question:
    {user_question}

    Provide a detailed and relevant answer based on the information from all the PDFs and the conversation history.

    Answer:
    """

    client = InferenceClient("mistralai/Mistral-Nemo-Instruct-2407", token=sec_key)
    response = client.text_generation(prompt, max_new_tokens=5000)
    if hasattr(response, 'generated_text'):
        return response.generated_text
    else:
        return response
# Out:
# tokenizer_config.json:   0%|          | 0.00/170 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/606 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/451M [00:00<?, ?B/s]
# Some weights of LayoutLMForSequenceClassification were not initialized from the model checkpoint at microsoft/layoutlm-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <ipython-input-4-66df94ddd026>:4: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embedder = HuggingFaceEmbeddings(model_name="all-mpnet-base-v2")
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
## Before implementing RAG

# %%
## First example with the prompt : When did the deadpool and wolverine movie released
def test_model_inference(user_question):
    sec_key = os.getenv("HUGGINGFACEHUB_API_TOKEN")

    prompt = f"""
    You are an assistant that provides detailed answers. The user has asked the following question:
    {user_question}

    Answer:
    """

    client = InferenceClient("mistralai/Mistral-Nemo-Instruct-2407", token=sec_key)
    response = client.text_generation(prompt, max_new_tokens=500)
    return response.generated_text if hasattr(response, 'generated_text') else response

user_question = "When did the deadpool and wolverine movie released"
response = test_model_inference(user_question)
print("Bot:", response)
# Out:
# Bot:  The Deadpool and Wolverine movie you're referring to is "Deadpool & Wolverine" which is a crossover comic book series, not a film. If you're asking about movies featuring these characters, here are the release dates:
#
#     - Deadpool (2016)
#     - Logan (Wolverine's solo film, 2017)
#     - Deadpool 2 (2018)
#     - Once Upon a Deadpool (2018, a PG-13 cut of Deadpool 2)

# %%
## Second example with the prompt : Tell the summary of ghostbusters:frozen empire movie

def test_model_inference(user_question):
    sec_key = os.getenv("HUGGINGFACEHUB_API_TOKEN")

    prompt = f"""
    You are an assistant that provides detailed answers. The user has asked the following question:
    {user_question}

    Answer:
    """

    client = InferenceClient("mistralai/Mistral-Nemo-Instruct-2407", token=sec_key)
    response = client.text_generation(prompt, max_new_tokens=500)
    return response.generated_text if hasattr(response, 'generated_text') else response

# Test the model with a sample question
user_question = "Tell the summary of ghostbusters:frozen empire movie"
response = test_model_inference(user_question)
print("Bot:", response)
# Out:
# Bot:  "Ghostbusters: Frozen Empire" is a 2021 American supernatural comedy film directed by Jason Reitman and Gil Kenan, and written by Dan Aykroyd, Jason Reitman, and Gil Kenan. It is a sequel to the 1989 film "Ghostbusters II" and the fourth installment in the Ghostbusters franchise.
#
#     The film is set in the fictional town of Summerville, Oklahoma, where a mysterious cold snap has caused the town to freeze over. The Ghostbusters, now consisting of Egon Spengler (Harold Ramis), Ray Stantz (Dan Aykroyd), Winston Zeddemore (Ernie Hudson), and a new recruit, Jillian Holtzmann (Kate McKinnon), are called in to investigate the phenomenon.
#
#     As they delve deeper into the mystery, they discover that the cold snap is the work of a powerful and ancient entity known as the "Frozen Empire," which is attempting to take over the world by freezing it. The Ghostbusters must use their knowledge of the paranormal and their advanced technology to stop the entity and save the world from a frozen fate.
#
#     Along the way, they encounter a variety of ghosts and other supernatural creatures, as well as a group of rival ghost hunters who are determined to steal their thunder. The film is filled with humor, action, and plenty of ghostly scares, as the Ghostbusters face their most challenging adventure yet.
#
#     In the end, the Ghostbusters are able to defeat the Frozen Empire and save the world from its icy grip. The film ends with a message about the importance of teamwork and the power of friendship, as the Ghostbusters reflect on their journey and the bonds they have formed.
#
#     "Ghostbusters: Frozen Empire" received mixed reviews from critics, who praised the film's humor and visual effects but criticized its plot and character development. Despite this, the film was a box office success, grossing over $286 million worldwide against a budget of $150 million. It is considered a fan favorite among Ghostbusters enthusiasts and has spawned a number of sequels and spin-offs.

# %%
## Third example with the prompt : Tell the name of the latest iphone,what are its capabilites

def test_model_inference(user_question):
    sec_key = os.getenv("HUGGINGFACEHUB_API_TOKEN")

    prompt = f"""
    You are an assistant that provides detailed answers. The user has asked the following question:
    {user_question}

    Answer:
    """

    client = InferenceClient("mistralai/Mistral-Nemo-Instruct-2407", token=sec_key)
    response = client.text_generation(prompt, max_new_tokens=500)
    return response.generated_text if hasattr(response, 'generated_text') else response

# Test the model with a sample question
user_question = "Tell the name of the latest iphone,what are its capabilites"
response = test_model_inference(user_question)
print("Bot:", response)
# Out:
# Bot:  The latest iPhone is the iPhone 14 Pro Max, released in September 2022. Here are some of its key capabilities:
#
#     - **Display**: 6.7-inch Super Retina XDR OLED display with ProMotion technology (120Hz adaptive refresh rate), HDR10, 1000 nits typical brightness, and 1600 nits peak brightness.
#
#     - **Processor**: A16 Bionic chip (5nm, 6-core CPU, 5-core GPU, 16-core Neural Engine).
#
#     - **Cameras**:
#       - **Rear**: 48MP main camera with sensor-shift optical image stabilization (OIS), 12MP ultrawide camera, and 12MP telephoto camera with 3x optical zoom.
#       - **Front**: 12MP TrueDepth camera.
#
#     - **Video**: Cinematic mode for 4K video recording at 24 fps, ProRes video recording, Dolby Vision HDR video recording, and Cinematic mode for video.
#
#     - **Battery**: Built-in rechargeable lithium-ion battery supporting MagSafe wireless charging (up to 15W), Qi wireless charging (up to 7.5W), and fast charging (up to 20W).
#
#     - **Storage**: Available in 128GB, 256GB, 512GB, and 1TB storage options.
#
#     - **Connectivity**: 5G (mmWave and sub-6GHz), Gigabit LTE, 802.11ax Wi‑Fi 6 with 2x2 MIMO, Bluetooth 5.3, Ultra Wideband (UWB) with Precision Finding, and NFC with reader mode.
#
#     - **Sensors**: Face ID, Barometric altimeter, Three-axis gyro, Accelerometer, Proximity sensor, Ambient light sensor, and Ultra Wideband (UWB) antenna.
#
#     - **Water Resistance**: Rated IP68 (maximum depth of 6 meters up to 30 minutes) under IEC standard 60529.
#
#     - **Colors**: Available in Space Black, Silver, Gold, and the new Deep Purple color.

# %%
## After implementing RAG

# %%
pdf_file_paths = ["Deadpool & Wolverine.pdf","Ghostbusters_ Frozen Empire.pdf","iPhone 16 Pro.pdf"]
pdf_text = extract_text_from_multiple_pdfs(pdf_file_paths)
vectorstore = create_faiss_index(pdf_text, embedder)
conversation_history = []
while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        break

    response = handle_user_input(user_input, vectorstore, conversation_history)
    print(f"Bot: {response}")
# Out:
# You: When did the deadpool and wolverine movie released
# Bot:  Deadpool & Wolverine was released on July 26, 2024, as part of Phase Five of the Marvel Cinematic Universe (MCU). The film premiered on July 22, 2024, at the David H. Koch Theater in New York City.
# You: exit

# %%
## Third Example
while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        break

    response = handle_user_input(user_input, vectorstore, conversation_history)
    print(f"Bot: {response}")
# Out:
# You: Tell the summary of ghostbusters:frozen empire movie
# Bot:  Ghostbusters: Frozen Empire is a 2024 American supernatural comedy film directed by Jason Reitman and written by Gil Kenan and Jason Reitman. It is the fourth installment in the Ghostbusters franchise, serving as a direct sequel to Ghostbusters: Afterlife (2021). The film follows the Spengler family, who have moved to New York City, as they join forces with the original Ghostbusters to combat a new ghost threat that has begun to terrorize the city.
#
#     The cast includes Paul Rudd as Gary Grooberson, Carrie Coon as Callie Spengler, Finn Wolfhard as Trevor Spengler, Mckenna Grace as Phoebe Spengler, Kumail Nanjiani as Nadeem Jaffrey, Patton Oswalt as Dr. Hubert Warkzinski, Celeste O'Connor as Lucky Domingo, Logan Kim as Podcast, Emily Alyn Lind as Melody, James Acaster as Dr. Lars Pinfield, Bill Murray as Dr. Peter Venkman, Dan Aykroyd as Dr. Raymond "Ray" Stantz, Ernie Hudson as Dr. Winston Zeddemore, and Annie Potts as Janine Melnitz.
#
#     Principal photography began on March 20, 2023, in London, under the working title Firehouse, with Eric Steelberg serving as the cinematographer. Filming was also spotted in New York City, where Casey Neistat was caught filming a stunt scene in a video posted on June 7, 2023. Filming wrapped on June 23.
#
#     The film had its world premiere at the AMC 13 Theater at Lincoln Square in New York City on March 14, 2024, and was released in the United States on March 22, by Sony Pictures Releasing under its Columbia Pictures label. It received mixed reviews from critics and grossed $201 million worldwide. A sequel is in development.
#
#     In the film, after the events in Summerville, Oklahoma, the Spengler family moves to New York City. When a new ghost threat begins to terrorize the city, they join forces with the original Ghostbusters to combat it. The Ghostbusters are hailed as heroes again, with Peck forced to support the team and reinstate Phoebe. The Ghostbusters begin pursuing escaped ghosts across New York City. In a mid-credits scene, a trucker gets out of his Stay Puft Marshmallows branded truck to make a purchase from a vending machine. The Mini-Pufts steal the vehicle in his absence.
# You: exit

# %%
## Second Example
while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        break

    response = handle_user_input(user_input, vectorstore, conversation_history)
    print(f"Bot: {response}")
# Out:
# You: Tell the name of the latest iphone,what r its capabilites
# Bot:  The latest iPhone models announced by Apple are the iPhone 16 and iPhone 16 Plus, as well as the iPhone 16 Pro and iPhone 16 Pro Max. Here are some of their capabilities based on the information extracted from the PDFs:
#
#     **iPhone 16 and iPhone 16 Plus:**
#     - Display: 6.1-inch and 6.7-inch Super Retina XDR OLED, 60Hz, HDR10, Dolby Vision, 1200 nits (typ), 1700 nits (HBM)
#     - Sound: Stereo speakers, Dolby Atmos
#     - Connectivity: Wi-Fi 6, Bluetooth 5.3, Ultra-wideband (UWB), NFC (reader mode, Express Cards), LEO satellite (Globalstar, limited)
#     - Camera: Dual 12MP camera system (Wide and Ultra Wide), 4K video recording at 24 fps, 30 fps, or 60 fps
#     - Battery: 3279 mAh (iPhone 16) and 4352 mAh (iPhone 16 Plus)
#     - Storage: 128GB, 256GB, or 512GB
#     - RAM: 6GB
#     - Processor: A18 Bionic chip
#     - Water resistance: IP68 (maximum depth of 6 meters up to 30 minutes)
#
#     **iPhone 16 Pro and iPhone 16 Pro Max:**
#     - Display: 6.3-inch and 6.9-inch LTPO Super Retina XDR OLED, 120Hz, HDR10, Dolby Vision, 1000 nits (typ), 2000 nits (HBM)
#     - Sound: Dolby Atmos-tuned Spatial Audio
#     - Connectivity: Wi-Fi 6, Bluetooth 5.3, Ultra-wideband (UWB), Thread, NFC (reader mode, Express Cards), LEO satellite (Globalstar, limited), USB-C: USB 3.2 10Gb/s
#     - Camera: Triple 12MP camera system (Wide, Ultra Wide, and Telephoto), 4K video recording at 24 fps, 30 fps, 60 fps, or 120 fps
#     - Battery: 3200 mAh (iPhone 16 Pro) and 4500 mAh (iPhone 16 Pro Max)
#     - Storage: 128GB, 256GB, 512GB, or 1TB
#     - RAM: 8GB (iPhone 16 Pro) and 12GB (iPhone 16 Pro Max)
#     - Processor: A18 Pro Bionic chip
#     - Water resistance: IP68 (maximum depth of 6 meters up to 30 minutes)
#
#     All iPhone 16 models feature:
#     - Dual-frequency GPS (L1, L5), GLONASS, Galileo, QZSS, BeiDou, NavIC
#     - Face ID
#     - MagSafe and Qi wireless charging
#     - USB-C fast-charge capable
#     - SIM: Dual SIM (nano-SIM and eSIM) or Dual eSIM (depending on the region)
# You: exit

# %%
###### 5 examples of Optimised prompts

# %%
pdf_file_paths = ["HR.pdf","IT.pdf","BANKING.pdf","FINANCE.pdf","CONSULTANT.pdf"]
pdf_text = extract_text_from_multiple_pdfs(pdf_file_paths)
vectorstore = create_faiss_index(pdf_text, embedder)
conversation_history = []

while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        break

    response = handle_user_input(user_input, vectorstore, conversation_history)
    print(f"Bot: {response}")


## Before optimised prompt: What qualities does the HR candidate have?
## After optimised prompt: What are the key qualities and strengths of the HR candidate in areas like employee engagement, conflict resolution, and talent acquisition? Describe any notable achievements or certifications in HR practices.
# Out:
# You: What qualities does the HR candidate have?
# Bot:
#
#     The HR candidate, based on the provided information, possesses the following qualities:
#
#     1. **People-oriented and Confidential**: The candidate is described as "people-oriented" and maintains confidentiality, which are crucial qualities for an HR executive.
#
#     2. **Organized and Efficient**: The candidate's experience in marketing and advertising highlights their ability to maintain organization, complete deadlines, and stay on task, indicating strong organizational skills.
#
#     3. **Exceptional Multi-Tasker**: The candidate's experience also mentions exceptional multi-tasking skills, which are essential in HR roles that often involve juggling multiple responsibilities.
#
#     4. **Motivated Team Player**: The candidate is described as a, which indicates their willingness.
#
#     , a quality.
#
#     , a quality.
#
#     1 , a quality.
#
#     The candidate, and the candidate.
#
#     quality.
#
#     The candidate and quality.
#
#     1. **1000 quality
#
#     quality
#
#     The candidate
#
#     2.
# You: What are the key qualities and strengths of the HR candidate in areas like employee engagement, conflict resolution, and talent acquisition? Describe any notable achievements or certifications in HR practices.
# Bot:  Based on the information provided, here are the key qualities and strengths of the HR candidate in the specified areas, along with notable achievements and certifications:
#
#     **Employee Engagement:**
#     - **People-oriented**: The candidate's people-oriented nature suggests a strong ability to engage with employees, understand their needs, and foster a positive work environment.
#     - **Identifying training and development opportunities**: The candidate's experience in identifying training and development opportunities indicates a proactive approach to employee growth and engagement.
#     - **Employee survey and secondary data analysis**: During internships, the candidate used employee surveys and secondary data to analyze growth and development needs, demonstrating a data-driven approach to employee engagement.
#
#     **Conflict Resolution:**
#     - **Provide advice and recommendations on disciplinary actions**: The candidate's experience in providing advice on disciplinary actions suggests a strong understanding of conflict resolution processes.
#     - **Maintains confidentiality**: The candidate's ability to maintain confidentiality is crucial in handling sensitive conflict resolution issues and ensuring employee trust.
#     - **Excellent communication skills**: The candidate's well-developed communication skills are essential for effective conflict resolution, as they enable clear and empathetic communication with all parties involved.
#
#     **Talent Acquisition:**
#     - **Prepare, develop, and implement procedures and policies on staff recruitment**: The candidate's experience in developing and implementing recruitment procedures and policies demonstrates a strong understanding of the talent acquisition process.
#     - **Prepare notices and advertisements for vacant staff positions**: The candidate's experience in preparing job advertisements indicates a good understanding of how to attract potential candidates.
#     - **Schedule and organize interviews**: The candidate's experience in scheduling and organizing interviews shows practical skills in the talent acquisition process.
#
#     **Notable Achievements:**
#     - **Nominated for Property of the Year**: In their current marketing position, the candidate led their property to be nominated for Property of the Year, demonstrating strong leadership and team management skills that could translate to HR roles.
#     - **3.7% increase in NOI**: The candidate's efforts contributed to a 3.7% increase in Net Operating Income (NOI) for their property, indicating a track record of driving results and improving key performance indicators.
#
#     **Certifications:**
#     - While the provided information does not mention any specific HR certifications, the candidate's dual specialization in Human Resource Management and Finance suggests a strong educational foundation in HR practices.
#     - The candidate's experience in HR roles, such as HR Management Trainee, also indicates practical knowledge and application of HR principles and best practices.
#
#     In conclusion, the HR candidate possesses a strong set of qualities and strengths in employee engagement, conflict resolution, and talent acquisition, backed by notable achievements and a solid educational foundation in HR practices.
# You: exit

# %%
while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        break

    response = handle_user_input(user_input, vectorstore, conversation_history)
    print(f"Bot: {response}")


## Before optimised prompt: What are the skills of the banking candidate?
## After optimised prompt: What unique skills and qualities make this candidate suited for banking? Highlight their experience in financial products, risk management, and any customer service achievements.
# Out:
# You: What are the skills of the banking candidate?
# Bot:  Based on the information provided in the PDFs and the conversation history, the banking candidate possesses a diverse set of skills, including both technical and soft skills, making them well-suited for various roles in the banking industry. Here's a detailed breakdown of their skills:
#
#     **Technical Skills:**
#
#     1. **Programming and Development:**
#        - Proficient in COBOL, a programming language commonly used in banking and finance industries.
#        - Experience in creating CICS MAP from scratch and developing the presentation layer and service programs.
#        - Familiarity with creating High-level design documents and providing architectural solutions.
#        - Experience in developing new programs to handle various functions of banking activities, both online and batch.
#
#     2. **Database and Data Management:**
#        - Experience in tracking and reporting all defects in the System Integration Testing (SIT) environment.
#        - Familiarity with creating Unit Test Plans (UTP) for service and online programs.
#        - Ability to work on testing parts, including STUB creation and other activities for performance tuning.
#
#     3. **Project Management:**
#        - Experience in coordinating various releases and taking responsibility for daily status reporting and follow-ups.
#        - Proactive resolution of functional/technical hurdles that could impact deliverables, ensuring timely and flawless delivery.
#        - Ability to create project plans and manage project timelines.
#
#     4. **Business Analysis:**
#        - Experience in providing technical specifications based on business requirements.
#        - Ability to perform strategic analysis and provide unique solutions to meet business needs.
#        - Familiarity with functional and organizational performance reviews and optimization.
#
#     **Soft Skills:**
#
#     1. **Communication:**
#        - Well-developed and effective communication skills, enabling clear and concise exchange of information with both technical and non-technical stakeholders.
#        - Ability to thrive in deadline-driven environments, demonstrating adaptability and resilience under pressure.
#
#     2. **Teamwork and Collaboration:**
#        - Excellent team-building skills, with experience in coordinating and working with cross-functional teams to deliver projects successfully.
#        - Ability to work effectively in a team, contributing to a positive and collaborative work environment.
#
#     3. **Problem-Solving:**
#        - Proven ability to identify problems and provide effective solutions, as demonstrated by proactively resolving functional/technical hurdles in banking projects.
#        - Strong analytical skills, enabling the candidate to evaluate complex situations and make informed decisions.
#
#     4. **Leadership:**
#        - Experience in providing leadership and mentoring to team members, fostering a culture of growth and development.
#        - Ability to create and maintain high-level design documents, demonstrating strong organizational and leadership skills.
#
#     5. **Adaptability:**
#        - Experience working in POC (Proof of Concept) environments, indicating a willingness to adapt to new situations and learn quickly.
#        - Ability to work effectively in both online and batch environments, showcasing versatility and adaptability.
#
#     In conclusion, the banking candidate brings a strong combination of technical and soft skills to the table, making them a valuable asset to any banking organization. Their diverse skill set enables them to contribute effectively to various roles, from development and project management to business analysis and leadership positions.
# You: What unique skills and qualities make this candidate suited for banking? Highlight their experience in financial products, risk management, and any customer service achievements.
# Bot:  The banking candidate possesses several unique skills and qualities that make them well-suited for a career in banking, with a particular focus on financial products, risk management, and customer service. Here's a detailed breakdown of their relevant experience and achievements:
#
#     **Financial Products:**
#
#     1. **Product Development and Management:**
#        - The candidate has experience in developing new programs to handle various functions of banking activities, both online and batch. This experience demonstrates their ability to contribute to the creation and management of financial products tailored to meet customer needs.
#        - Their familiarity with creating High-level design documents and providing architectural solutions indicates a strong understanding of product design and development processes in the banking context.
#
#     2. **Financial Operations:**
#        - The candidate's experience in providing design proposals and developing new programs for various functions of banking activities suggests a solid understanding of financial operations and the ability to contribute to the improvement and expansion of banking product offerings.
#
#     **Risk Management:**
#
#     1. **Risk Assessment and Mitigation:**
#        - The candidate's experience in proactively resolving functional/technical hurdles that could impact deliverables demonstrates their ability to identify and mitigate risks in banking projects.
#        - Their involvement in creating High-level design documents and providing architectural solutions indicates a proactive approach to risk management, as they consider potential issues and implement preventive measures during the product development phase.
#
#     2. **Compliance and Regulatory Knowledge:**
#        - While the provided information does not explicitly mention compliance or regulatory knowledge, the candidate's experience in working with enterprise platforms and business continuity/disaster recovery suggests a familiarity with the importance of compliance and adherence to regulatory standards in banking.
#
#     **Customer Service:**
#
#     1. **Customer Service Focus:**
#        - The candidate's experience in customer service-focused roles, such as their position in marketing and public relations, indicates a strong customer-centric mindset that can be applied to banking roles.
#        - Their ability to maintain confidentiality, as mentioned in their marketing experience, is a crucial skill in banking, where customer data and information must be protected.
#
#     2. **Customer Service Achievements:**
#        - Although the provided information does not mention specific customer service achievements in the banking context, the candidate's experience in marketing and advertising highlights their ability to maintain organization, complete deadlines, and stay on task, which are essential skills for delivering excellent customer service.
#        - Their nomination for Property of the Year in their current marketing position demonstrates their ability to drive results and exceed customer expectations, which can translate to success in banking customer service roles.
#
#     In conclusion, the banking candidate's unique skills and qualities, including their experience in financial products, risk management, and customer service, make them a strong fit for a career in banking. Their diverse background and proven track record of success in related fields position them well to contribute effectively to banking roles focused on product development, risk management, and customer service.
# You: exit

# %%
while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        break

    response = handle_user_input(user_input, vectorstore, conversation_history)
    print(f"Bot: {response}")



## Before optimised prompt: What makes the IT candidate a good fit?
## After optimised prompt: What qualities and technical skills make this candidate a strong fit for IT? Focus on their programming expertise, problem-solving abilities, and experience with recent technology projects.
# Out:
# You: What makes the IT candidate a good fit?
# Bot:  The IT candidate is a strong fit for various IT roles due to their extensive experience, diverse skill set, and proven track record of success in IT management, strategy, and project delivery. Here's a detailed breakdown of what makes the IT candidate a good fit, based on the information from the PDFs and the conversation history:
#
#     **1. Proven IT Management and Leadership Experience:**
#
#     - The IT candidate has held multiple leadership positions, including Vice President of Information Technology, System Administrator, and IT Director. This extensive experience demonstrates their ability to manage and lead IT teams effectively.
#     - In their role as Vice President of Information Technology, the candidate built and improved IT organizations, turning around underperforming teams and making IT a strategic partner of the company. This experience showcases their ability to drive change and deliver results in IT management.
#     - As an IT Director, the candidate managed a team of six, overseeing IT infrastructure and business intelligence operations for a large United Way organization with a $38M revenue. This experience highlights their ability to lead teams and manage IT operations in a complex, high-stakes environment.
#
#     **2. Broad IT Skill Set:**
#
#     - The IT candidate possesses a wide range of technical skills, including:
#       - IT strategy and management
#       - Project management
#       - Business intelligence
#       - Cloud computing
#       - IT infrastructure
#       - Enterprise platforms
#       - Business continuity and disaster recovery
#       - Budgeting and cost control
#       - IT compliance (SOX, HIPAA, GLBA)
#     - This diverse skill set enables the candidate to contribute effectively to various IT roles and projects, from strategic planning to day-to-day operations and project delivery.
#
#     **3. Successful IT Project Delivery:**
#
#     - The IT candidate has a consistent record of delivering major IT-dependent projects on time and under budget. These projects include office moves, subsidiary acquisition and divestiture, network redesign, and software deployment.
#     - In their role as an IT Director, the candidate engineered the strategic evolution of Salesforce CRM, implementing email marketing, event registration, credit card purchasing, and volunteer management systems. They also designed and executed the IT portion of a corporate headquarters move to a new 64,000 sq. ft. building with zero downtime.
#     - These successful project deliveries demonstrate the candidate's ability to manage complex IT initiatives, meet deadlines, and control costs.
#
#     **4. Cost Management and Savings:**
#
#     - The IT candidate has a proven track record of reducing IT costs. As a System Administrator, they decreased the annual IT budget by at least $50K each year from 2003 to 2006. In their role as an IT Director, the candidate managed a $1M annual IT budget with an emphasis on cost savings and value-based solutions.
#     - This experience indicates the candidate's ability to identify and implement cost-saving measures while maintaining or improving IT services and performance.
#
#     **5. Strong Communication and Team-Building Skills:**
#
#     - The IT candidate's experience in various leadership roles highlights their strong communication skills, both in terms of working with technical teams and stakeholders and in driving IT strategy and change management.
#     - Their excellent team-building skills have enabled them to create and lead high-performing IT teams, fostering a collaborative and productive work environment.
#
#     **6. Adaptability and Continuous Learning:**
#
#     - The IT candidate's experience working with various technologies, industries, and organizations demonstrates their ability to adapt to new environments and learn quickly.
#     - Their continuous learning approach, as evidenced by their experience in building, improving, and turning around IT organizations, indicates a commitment to staying up-to-date with the latest IT trends and best practices.
#
#     In conclusion, the IT candidate's extensive experience, diverse skill set, proven track record of success, and strong leadership qualities make them an excellent fit for various IT roles. Their ability to manage and deliver complex IT projects, control costs, and drive IT strategy positions them well to contribute effectively to any organization's IT goals.
# You: What qualities and technical skills make this candidate a strong fit for IT? Focus on their programming expertise, problem-solving abilities, and experience with recent technology projects.
# Bot:  The IT candidate's strong fit for IT roles is evident in their extensive programming expertise, exceptional problem-solving abilities, and experience with recent technology projects. Here's a detailed breakdown of these qualities and skills, based on the information from the PDFs and the conversation history:
#
#     **1. Programming Expertise:**
#
#     - The IT candidate has a solid foundation in programming, with experience in various languages and technologies. Their experience includes:
#       - COBOL: Proficient in COBOL, a programming language commonly used in banking and finance industries, with experience in creating CICS MAP from scratch and developing the presentation layer and service programs.
#       - JCL: Familiarity with Job Control Language (JCL) for submitting and controlling jobs in a mainframe environment.
#       - DB2: Experience with DB2, a relational database management system, including tools such as QMF, SPUFI, FILE-AID, DB2 Admin, and DB2 command editor.
#       - UNIX: Experience working in a UNIX environment, with hands-on experience using debugging tools such as XPEDITOR and IBM DEBUGER.
#       - Configuration management tools: Expertise in using configuration management tools like Endevor and SCLM.
#     - The candidate's programming expertise enables them to contribute effectively to software development, maintenance, and improvement projects in various IT roles.
#
#     **2. Problem-Solving Abilities:**
#
#     - The IT candidate has demonstrated exceptional problem-solving abilities throughout their career, as evidenced by:
#       - Proactively resolving functional/technical hurdles that could impact deliverables, ensuring timely and flawless delivery of banking projects.
#       - Identifying problems and providing effective solutions, as demonstrated by their ability to turn around underperforming IT teams and make IT a strategic partner of the company.
#       - Their experience in creating High-level design documents and providing architectural solutions indicates a strong problem-solving approach, as they consider potential issues and implement preventive measures during the product development phase.
#       - The candidate's ability to work effectively in both online and batch environments showcases their adaptability and problem-solving skills in diverse IT contexts.
#     - The IT candidate's strong problem-solving abilities enable them to tackle complex IT challenges, identify root causes, and implement effective solutions, contributing to improved IT performance and outcomes.
#
#     **3. Experience with Recent Technology Projects:**
#
#     - The IT candidate has worked on various recent technology projects, demonstrating their ability to stay current with the latest trends and tools in the IT industry. Some of their recent projects and experiences include:
#       - **Cloud Computing**: The candidate has experience in cloud computing, with a focus on leveraging best-in-class infrastructures to create IT competitive advantages in capability and scale.
#       - **Enterprise Platforms**: The candidate's experience working with enterprise platforms indicates their familiarity with large-scale, complex IT systems and their ability to manage and optimize these platforms for improved performance and efficiency.
#       - **Business Intelligence**: The candidate has experience in business intelligence, with a focus on leveraging data and analytics to drive informed decision-making and improve IT performance.
#       - **IT Infrastructure**: The candidate's experience in managing IT infrastructure, including firewalls, routers, switches, and Wi-Fi systems, demonstrates their ability to design, implement, and maintain robust and secure IT environments.
#       - **IT Strategy**: The candidate's experience in developing and implementing IT strategy indicates their ability to align IT with business objectives, drive IT-enabled innovation, and create competitive advantages through technology.
#     - The IT candidate's experience with recent technology projects positions them well to contribute effectively to cutting-edge IT initiatives, helping organizations to leverage the latest tools and trends to drive growth and improve performance.
#
#     In conclusion, the IT candidate's strong fit for IT roles is evident in their extensive programming expertise, exceptional problem-solving abilities, and experience with recent technology projects. Their diverse skill set, combined with their proven track record of success in IT management, strategy, and project delivery, makes them an excellent candidate for various IT positions. Their ability to adapt to new technologies and environments, coupled with their strong leadership and communication skills, enables them to drive IT strategy, deliver complex projects, and create value for organizations in the ever-evolving IT landscape.
# You: ext
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-240f85c7fdc9> in <cell line: 1>()
#       5         break
#       6
# ----> 7     response = handle_user_input(user_input, vectorstore, conversation_history)
#       8     print(f"Bot: {response}")
#
# <ipython-input-6-66df94ddd026> in handle_user_input(user_question, vectorstore, conversation_history)
#      37     relevant_text = retriever.get_relevant_documents(user_question)
#      38
# ---> 39     response = generate_response_from_inference_api(user_question, relevant_text, conversation_history)
#      40
#      41     conversation_history.append({"user": user_question, "bot": response})
#
# <ipython-input-6-66df94ddd026> in generate_response_from_inference_api(user_question, relevant_text, conversation_history)
#      70
#      71     client = InferenceClient("mistralai/Mistral-Nemo-Instruct-2407", token=sec_key)
# ---> 72     response = client.text_generation(prompt, max_new_tokens=5000)
#      73     if hasattr(response, 'generated_text'):
#      74         return response.generated_text
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/inference/_client.py in text_generation(self, prompt, details, stream, model, adapter_id, best_of, decoder_input_details, do_sample, frequency_penalty, grammar, max_new_tokens, repetition_penalty, return_full_text, seed, stop_sequences, temperature, top_k, top_n_tokens, top_p, truncate, typical_p, watermark)
#    2144         # Handle errors separately for more precise error messages
#    2145         try:
# -> 2146             bytes_output = self.post(json=payload, model=model, task="text-generation", stream=stream)  # type: ignore
#    2147         except HTTPError as e:
#    2148             match = MODEL_KWARGS_NOT_USED_REGEX.search(str(e))
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/inference/_client.py in post(self, json, data, model, task, stream)
#     287             with _open_as_binary(data) as data_as_binary:
#     288                 try:
# --> 289                     response = get_session().post(
#     290                         url,
#     291                         json=json,
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in post(self, url, data, json, **kwargs)
#     635         """
#     636
# --> 637         return self.request("POST", url, data=data, json=json, **kwargs)
#     638
#     639     def put(self, url, data=None, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_http.py in send(self, request, *args, **kwargs)
#      64         """Catch any RequestException to append request id to the error message for debugging."""
#      65         try:
# ---> 66             return super().send(request, *args, **kwargs)
#      67         except requests.RequestException as e:
#      68             request_id = request.headers.get(X_AMZN_TRACE_ID)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787
#     788             # Make the request on the HTTPConnection object
# --> 789             response = self._make_request(
#     790                 conn,
#     791                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534         # Receive the response from the server
#     535         try:
# --> 536             response = conn.getresponse()
#     537         except (BaseSSLError, OSError) as e:
#     538             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     505
#     506         # Get the response from http.client.HTTPConnection
# --> 507         httplib_response = super().getresponse()
#     508
#     509         try:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1301                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302                   self.__class__)
# -> 1303             return self.read(nbytes, buffer)
#    1304         else:
#    1305             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1157         try:
#    1158             if buffer is not None:
# -> 1159                 return self._sslobj.read(len, buffer)
#    1160             else:
#    1161                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        break

    response = handle_user_input(user_input, vectorstore, conversation_history)
    print(f"Bot: {response}")



## Before optimised prompt: What are the strengths of the finance candidate?
## After optimised prompt: What are the finance candidate’s strengths in areas like financial analysis, regulatory compliance, and cost management? Include any noteworthy achievements or tools they specialize in.
# Out:
# You: What are the strengths of the finance candidate?
# Bot:  The finance candidate's strengths are the following:
#     - Strong financial skills and knowledge
#     - Experience in financial analysis and reporting
#     - Ability to manage and analyze financial data
#     - Strong financial analysis skills
#     - Ability to analyze financial data and identify trends
#     - Strong financial analysis skills
#     - Ability to analyze financial data and identify trends
#     - Ability to analyze financial data and identify trends
#     - Ability to analyze financial data and identify trends
# You: What are the finance candidate’s strengths in areas like financial analysis, regulatory compliance, and cost management? Include any noteworthy achievements or tools they specialize in.
# Bot:  The finance candidate's strengths in financial analysis, regulatory compliance, and cost management are evident in their extensive experience and notable achievements in these areas. Here's a detailed breakdown of their key strengths and accomplishments:
#
#     **1. Financial Analysis:**
#
#     - **Expertise in Financial Analysis Tools**: The candidate is proficient in various financial analysis tools and software, including:
#       - Microsoft Excel: The candidate has a strong command of Excel, using it to create complex financial models, perform data analysis, and generate reports.
#       - Hyperion Planning: The candidate has experience with Hyperion Planning, a budgeting and forecasting tool, enabling them to create and manage financial plans and projections.
#       - Cognos TM1: The candidate is familiar with Cognos TM1, a multidimensional database and planning tool, allowing them to build and maintain complex financial models.
#       - Anaplan: The candidate has experience with Anaplan, a cloud-based planning and performance management platform, demonstrating their ability to work with cutting-edge financial analysis tools.
#     - **Financial Analysis Skills**: The candidate possesses strong financial analysis skills, as demonstrated by:
#       - Their ability to analyze financial statements, identify trends, and make data-driven decisions.
#       - Their experience in creating and maintaining financial models, budgets, and forecasts.
#       - Their ability to perform variance analysis, comparing actual results to budgeted or forecasted figures, and identify the reasons for any differences.
#       - Their experience in conducting break-even analysis, cost-volume-profit analysis, and other financial analysis techniques to support strategic decision-making.
#     - **Noteworthy Achievements**: The candidate's notable achievements in financial analysis include:
#       - Developing and implementing a new budgeting and forecasting process that reduced the time required for budget preparation by 50% and improved the accuracy of financial projections.
#       - Creating a comprehensive financial model for a major acquisition, enabling the candidate's organization to make an informed decision about the transaction and successfully integrate the acquired company.
#
#     **2. Regulatory Compliance:**
#
#     - **Knowledge of Regulatory Requirements**: The candidate has a solid understanding of regulatory requirements in the finance industry, including:
#       - Sarbanes-Oxley Act (SOX): The candidate is familiar with the requirements of SOX, such as internal controls and financial reporting, and has experience implementing and maintaining SOX compliance programs.
#       - Generally Accepted Accounting Principles (GAAP): The candidate has a strong understanding of GAAP and experience in preparing financial statements in accordance with GAAP.
#       - Other regulatory requirements: The candidate is familiar with other regulatory requirements, such as those related to anti-money laundering (AML) and know your customer (KYC) procedures, as well as those specific to the candidate's industry and organization.
#     - **Regulatory Compliance Experience**: The candidate's experience in regulatory compliance includes:
#       - Serving as the primary point of contact for external auditors and regulatory bodies, ensuring that the organization is in compliance with relevant regulations.
#       - Implementing and maintaining internal controls to prevent and detect errors and fraud, as well as to ensure the accuracy of financial reporting.
#       - Conducting regular reviews of the organization's compliance with regulatory requirements and making recommendations for improvement.
#     - **Noteworthy Achievements**: The candidate's notable achievements in regulatory compliance include:
#       - Leading a successful SOX 404 compliance program, resulting in no material weaknesses or significant deficiencies identified by the external auditors.
#       - Implementing an AML/KYC program that helped the candidate's organization avoid regulatory fines and reputational damage.
#
#     **3. Cost Management:**
#
#     - **Cost Management Skills**: The candidate has strong cost management skills, as demonstrated by:
#       - Their ability to analyze and control costs, identify cost-saving opportunities, and implement cost reduction initiatives.
#       - Their experience in creating and maintaining cost centers, cost allocation methods, and cost accounting systems.
#       - Their ability to perform cost-benefit analysis, comparing the costs and benefits of various courses of action to make informed decisions about resource allocation.
#     - **Cost Management Experience**: The candidate's experience in cost management includes:
#       - Developing and maintaining cost budgets and forecasts, and tracking actual costs to ensure that the organization stays within its cost targets.
#       - Identifying and implementing cost-saving measures, such as process improvements, outsourcing, and renegotiating contracts with vendors.
#       - Conducting regular reviews of costs and making data-driven decisions about resource allocation and cost reduction.
#     - **Noteworthy Achievements**: The candidate's notable achievements in cost management include:
#       - Identifying and implementing cost-saving measures that resulted in a 15% reduction in operating expenses for the candidate's organization.
#       - Developing and maintaining a cost accounting system that improved the accuracy of cost reporting and enabled the candidate's organization to make more informed decisions about resource allocation.
#
#     In conclusion, the finance candidate's strengths in financial analysis, regulatory compliance, and cost management are evident in their extensive experience and notable achievements in these areas. Their strong financial skills and knowledge, combined with their ability to manage and analyze financial data, enable them to make a significant impact in various finance roles. Their experience with financial analysis tools, familiarity with regulatory requirements, and cost management skills position them well to contribute effectively to organizations seeking to improve their financial performance and compliance.
# You: exit

# %%
while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        break

    response = handle_user_input(user_input, vectorstore, conversation_history)
    print(f"Bot: {response}")



## Before optimised prompt: What are the qualities of the consultant candidate?
## After optimised prompt: What are the top qualities of this consulting candidate, particularly in client relationship management, strategic planning, and project leadership? Describe any significant achievements in client outcomes or process improvements.
# Out:
# You: What are the qualities of the consultant candidate?
# Bot:  The consultant candidate possesses a unique blend of skills, experiences, and qualities that make them an excellent fit for consulting roles. Based on the information from the PDFs and the conversation history, here's a detailed breakdown of the consultant candidate's key qualities:
#
#     **1. Strong Business Acumen:**
#
#     - **Industry Experience**: The candidate has extensive experience in various industries, including property management, public speaking, advertising, and media relations. This diverse industry background enables them to quickly understand and adapt to new business environments.
#     - **Strategic Thinking**: The candidate's experience in strategic brand management and PR campaigns demonstrates their ability to think strategically and develop effective solutions to complex business challenges.
#     - **Financial Awareness**: The candidate's experience in budget creation and management, as well as their ability to optimize rents based on market conditions, indicates a strong understanding of financial principles and their application in business contexts.
#
#     **2. Excellent Communication Skills:**
#
#     - **Superb Writing and Speaking Skills**: The candidate's exceptional writing and speaking skills enable them to communicate effectively with target audiences, both internally and externally, through strategic brand management and PR campaigns.
#     - **Charismatic and Persuasive**: The candidate's charismatic and persuasive nature allows them to build strong relationships, influence stakeholders, and drive consensus around strategic initiatives.
#     - **Excellent Presentation Skills**: The candidate's experience in public speaking and media relations indicates their ability to deliver compelling presentations and represent organizations effectively in various forums.
#
#     **3. Proven Leadership and Team Management Skills:**
#
#     - **Motivated Team Player**: The candidate's experience in leading teams and driving results, as demonstrated by their nomination for Property of the Year, showcases their ability to motivate and inspire team members to achieve organizational goals.
#     - **Mentoring and Leadership**: The candidate's experience in mentoring team members and providing advice on disciplinary actions indicates their ability to develop and support the growth of their team members.
#     - **Project Management**: The candidate's experience in overseeing marketing efforts, managing advertising budgets, and organizing financial reports demonstrates their strong project management skills and ability to juggle multiple responsibilities effectively.
#
#     **4. Adaptability and Continuous Learning:**
#
#     - **Quick Learner**: The candidate's ability to adapt to new situations and learn quickly, as evidenced by their experience in POC (Proof of Concept) environments, enables them to hit the ground running in new consulting engagements.
#     - **Versatile Experience**: The candidate's diverse experience in marketing, advertising, public relations, and property management indicates their ability to apply their skills and knowledge to a wide range of consulting projects and industries.
#
#     **5. Customer Service Focus:**
#
#     - **Customer-Centric Mindset**: The candidate's experience in customer service-focused roles and their ability to maintain organization and complete deadlines, as demonstrated by their experience in marketing and advertising, showcase their commitment to delivering exceptional customer service.
#     - **Market Research and Analysis**: The candidate's experience in studying the market, identifying trends, and optimizing rents based on market conditions indicates their ability to understand and address customer needs effectively.
#
#     **6. Notable Achievements:**
#
#     - **Property of the Year Nomination**: The candidate's nomination for Property of the Year demonstrates their ability to drive results and exceed expectations in their role as a marketing manager.
#     - **Increased Occupied Rent**: The candidate's efforts in increasing their property's occupied rent by over $100 and continuing to rise indicate their ability to identify and capitalize on opportunities to improve financial performance.
#
#     In conclusion, the consultant candidate's unique blend of strong business acumen, excellent communication skills, proven leadership and team management skills, adaptability, and customer service focus makes them an ideal fit for consulting roles. Their diverse industry experience, strategic thinking, and ability to deliver results position them well to contribute effectively to organizations seeking to improve their performance, drive growth, and navigate complex business challenges.
# You: What are the top qualities of this consulting candidate, particularly in client relationship management, strategic planning, and project leadership? Describe any significant achievements in client outcomes or process improvements.
# Bot:  Based on the information provided, here are the top qualities of the consulting candidate in client relationship management, strategic planning, and project leadership, along with significant achievements in client outcomes and process improvements:
#
#     **1. Client Relationship Management:**
#
#     - **Exceptional Communication Skills**: The candidate's superb writing and speaking skills, along with their charismatic and persuasive nature, enable them to build strong, lasting relationships with clients. They can effectively understand client needs, manage expectations, and provide tailored solutions.
#     - **Active Listening**: The candidate's ability to listen actively to clients and stakeholders, as demonstrated by their experience in customer service-focused roles, ensures that they understand and address client needs effectively.
#     - **Trust and Confidentiality**: The candidate's experience in maintaining confidentiality in marketing and public relations roles indicates their ability to build trust with clients and handle sensitive information responsibly.
#     - **Proactive Approach**: The candidate's proactive approach to identifying and addressing client needs, as evidenced by their experience in studying the market and optimizing rents based on market conditions, ensures that they anticipate and meet client expectations.
#
#     **Achievements in Client Outcomes:**
#
#     - **Increased Occupied Rent**: The candidate's efforts in increasing their property's occupied rent by over $100 and continuing to rise demonstrate their ability to drive positive client outcomes and improve financial performance.
#     - **Property of the Year Nomination**: The candidate's nomination for Property of the Year indicates their ability to exceed client expectations and deliver exceptional results in their role as a marketing manager.
#
#     **2. Strategic Planning:**
#
#     - **Strategic Thinking**: The candidate's experience in strategic brand management and PR campaigns, as well as their ability to optimize rents based on market conditions, showcases their ability to develop and implement effective strategic plans.
#     - **Data-Driven Decision Making**: The candidate's experience in analyzing financial data, identifying trends, and making data-driven decisions enables them to develop strategic plans that are grounded in reality and focused on delivering results.
#     - **Cross-Functional Collaboration**: The candidate's experience in working with cross-functional teams, as demonstrated by their role in overseeing marketing efforts and managing advertising budgets, indicates their ability to develop strategic plans that consider the perspectives and needs of various stakeholders.
#
#     **Achievements in Strategic Planning:**
#
#     - **Successful Acquisition Integration**: The candidate's experience in creating a comprehensive financial model for a major acquisition, enabling their organization to make an informed decision about the transaction and successfully integrate the acquired company, demonstrates their ability to develop and execute effective strategic plans.
#
#     **3. Project Leadership:**
#
#     - **Project Management Skills**: The candidate's experience in overseeing marketing efforts, managing advertising budgets, and organizing financial reports indicates their strong project management skills and ability to juggle multiple responsibilities effectively.
#     - **Team Leadership and Mentoring**: The candidate's experience in leading teams and driving results, as well as their ability to mentor team members and provide advice on disciplinary actions, showcases their ability to lead projects and develop high-performing teams.
#     - **Adaptability and Problem-Solving**: The candidate's experience in working in POC (Proof of Concept) environments and their ability to adapt to new situations quickly enable them to lead projects effectively, even in the face of unexpected challenges or changes.
#     - **Stakeholder Management**: The candidate's excellent communication skills, combined with their experience in working with cross-functional teams and managing client relationships, indicate their ability to manage stakeholders effectively and ensure that projects meet their needs and expectations.
#
#     **Achievements in Project Leadership:**
#
#     - **Turnaround Operations**: The candidate's experience in turning around underperforming programs and building credibility with executive teams and staff demonstrates their ability to lead projects that deliver significant improvements in performance and outcomes.
#     - **Successful Office Move**: The candidate's experience in engineering the strategic evolution of Salesforce CRM and designing and executing the IT portion of a corporate headquarters move to a new 64,000 sq. ft. building with zero downtime showcases their ability to lead complex projects successfully.
#
#     In conclusion, the consulting candidate's top qualities in client relationship management, strategic planning, and project leadership, combined with their significant achievements in client outcomes and process improvements, make them an excellent fit for consulting roles focused on driving client success and delivering results. Their strong business acumen, excellent communication skills, and proven leadership abilities position them well to lead complex projects, build strong client relationships, and develop effective strategic plans that meet the unique needs and challenges of each engagement.
# You: exit
